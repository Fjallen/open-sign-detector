# %%
import keras
from tensorflow.keras import layers,models
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
trainset = []

# %%
# load images
for i in range(0,80,2):
    name = "ups/uparrow" + str(i) + ".jpg"
    image = cv2.imread(name)
    reSized = cv2.resize(image,(32,32))
    trainset.append(reSized)

# %%
# load nones
for i in range(0,10):
    name="none/none"+str(i)+".jpg"
    image = cv2.imread(name)
    reSized = cv2.resize(image,(32,32))
    trainset.append(reSized)

# %%
train_set = np.asarray(trainset)

# %%
train_set.shape
# Out:
# (50, 32, 32, 3)

# %%
train_label[39]
# Out:
# 0

# %%
train_label = []
for i in range(40):
    train_label.append(0)
for i in range(10):
    train_label.append(1)

# %%
len(train_label)
# Out:
# 50

# %%
train_label = np.asarray(train_label)

# %%
train_label[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-49ec3a089d75> in <module>
# ----> 1 train_label[1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
train_set.shape
# Out:
# (80, 32, 32, 3)

# %%
#Images loaded

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
# nvm i need smaller images

# %%
image = cv2.imread("uparrow125.jpg")
scaleDown = 1;

# %%
newImg = cv2.resize(image,(640,480))

# %%
plt.imshow(newImg)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_set, train_label, epochs=10)
# Out:
# Train on 50 samples
# Epoch 1/10
# 50/50 [==============================] - 0s 9ms/sample - loss: 13.3688 - accuracy: 0.3200
# Epoch 2/10
# 50/50 [==============================] - 0s 960us/sample - loss: 1.6141 - accuracy: 0.9200
# Epoch 3/10
# 50/50 [==============================] - 0s 960us/sample - loss: 3.1640 - accuracy: 0.5200
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/sample - loss: 5.8964 - accuracy: 0.8000
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/sample - loss: 4.2501 - accuracy: 0.8000
# Epoch 6/10
# 50/50 [==============================] - 0s 960us/sample - loss: 0.0500 - accuracy: 0.9800
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/sample - loss: 2.8610e-08 - accuracy: 1.0000
# Epoch 8/10
# 50/50 [==============================] - 0s 960us/sample - loss: 0.0854 - accuracy: 0.9800
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/sample - loss: 1.9890e-05 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
y_prob = model.predict(testingSet) 
y_classes = y_prob.argmax(axis=-1)

# %%
y_classes
# Out:
# array([0, 1, 1, 1], dtype=int64)

# %%
sign1 = cv2.imread("ups/uparrow0.jpg")
s1 = cv2.resize(sign1,(32,32))

# %%
none1 = cv2.imread("none/none1.jpg")
n1 = cv2.resize(none1,(32,32))

# %%
sign2 = cv2.imread("ups/uparrow200.jpg")
s2 = cv2.resize(sign2,(32,32))

# %%
fl = cv2.imread("flower.jpg")
flower = cv2.resize(fl,(32,32))

# %%
plt.imshow(flower)

# %%
testingSet = np.array((s1,s2,n1,flower), dtype=np.float32)

# %%
testingSet.shape
# Out:
# (4, 32, 32, 3)

# %%
z = cv2.imread("ups/uparrow0.jpg")

# %%
plt.imshow(s2)

# %%
plt
# Out:
# array([[[108., 121., 113.],
#         [106., 116., 110.],
#         [ 30.,  30.,  36.],
#         ...,
#         [ 22.,  72., 172.],
#         [ 14.,  59., 164.],
#         [ 26.,  78., 178.]],
#
#        [[ 85.,  96.,  94.],
#         [ 25.,  26.,  24.],
#         [ 25.,  28.,  29.],
#         ...,
#         [ 18.,  70., 170.],
#         [ 14.,  61., 166.],
#         [ 25.,  77., 178.]],
#
#        [[ 58.,  66.,  67.],
#         [ 17.,  22.,  22.],
#         [140., 150., 148.],
#         ...,
#         [ 21.,  74., 174.],
#         [ 14.,  61., 166.],
#         [ 26.,  78., 178.]],
#
#        ...,
#
#        [[188., 194., 189.],
#         [188., 194., 189.],
#         [191., 194., 188.],
#         ...,
#         [192., 195., 193.],
#         [ 47.,  47.,  38.],
#         [ 49.,  47.,  37.]],
#
#        [[189., 195., 190.],
#         [192., 198., 193.],
#         [170., 174., 163.],
#         ...,
#         [189., 195., 190.],
#         [182., 188., 183.],
# ...
